# %% [markdown]
# # Notebook 1: Python - The Basics
#
# ## 1. Jupyter Notebook Themes
# - **Installation and Upgrade**
#   - Install `jupyterthemes`: `!pip install jupyterthemes`
#   - Upgrade `jupyterthemes`: `!pip install --upgrade jupyterthemes`
# - **List Available Themes**: `!jt -l`
# - **Change Current Theme**: `!jt -t solarizedl`
# - **Restore Default Theme**: `!jt -r`
#
# ## 2. Introduction to Python
# - **Guido Van Rossum**: Mention of the creator of Python with an image.
# - **Why Python?**
#   - General purpose
#   - High-level language
#   - Easy to learn
#   - Dynamically typed
#   - Exceptional community support
#   - Huge library ecosystem
#
# ## 3. Recommended Books
# - *Intro to Python for Computer Science and Data Science: Learning to Program with AI, Big Data and The Cloud*
# - *Python Crash Course, 2nd Edition: A Hands-On, Project-Based Introduction to Programming*
#
# ---
#
# # Notebook 2: Python for Data Science and AI
#
# ## 1. Learning Python for Data Science and AI
# - **Introduction**
#   - Basic setup for Jupyter, similar to Notebook 1.
#
# ## 2. Basic Python Syntax
# - **Printing "Hello World"**: Example of outputting text.
# - **Basic Data Types**: Introduction to strings, integers, floats, and booleans.
# - **Variables**: How to declare and use variables.
# - **Basic Operations**: Arithmetic operations and their usage.
#
# ## 3. Control Structures
# - **Conditional Statements**: `if`, `elif`, and `else` examples.
# - **Loops**: Introduction to `for` and `while` loops.
#
# ## 4. Functions
# - **Defining Functions**: Syntax for creating functions.
# - **Arguments and Return Values**: How to pass parameters and return results.
#
# ## 5. Data Structures
# - **Lists**: Creating and manipulating lists.
# - **Dictionaries**: Understanding key-value pairs.
# - **Tuples**: Using immutable sequences.
#
# ## 6. Importing Libraries
# - Common libraries for data science (e.g., `numpy`, `pandas`, `matplotlib`).
# - Basic usage examples for each library.
#
# ---
#
# ## Logical Dependencies
# - **Setting Up the Environment**: Both notebooks emphasize starting with Jupyter themes to enhance user experience.
# - **Basic Syntax and Operations**: Introduced early to build a foundational understanding of Python.
# - **Control Structures and Functions**: Progressing to more complex programming concepts that rely on the basics learned.
# - **Data Structures**: Understanding how to organize data effectively, which is critical for data analysis and manipulation.
# - **Library Usage**: Essential for expanding Python’s capabilities, particularly for data science applications.
