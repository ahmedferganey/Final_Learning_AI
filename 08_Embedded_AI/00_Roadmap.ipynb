# %% [markdown]
# ```plaintext
# Autonomous-Engineer-Portfolio/
# ├── README.md  # Overview and roadmap
# ├── AOSP_AAOS/
# │   └── VehicleHAL_Demo/
# ├── Embedded_AI/
# │   ├── Jetson_LaneDetection/
# │   └── PyCUDA_ImageProcessing/
# ├── Microservices/
# │   ├── SensorDataAPI_FastAPI/
# │   └── Cloud_MQTT_Dashboard/
# ├── Tests_Validation/
# │   └── HIL_Test_Framework/
# ├── Docs/
# │   ├── Resume.pdf
# │   └── LinkedIn_Summary.md
# ```

# %% [markdown]
# # 🛣️ Roadmap: Embedded AI Engineer for Autonomous Vehicles & Real-Time Computer Vision (Eagle Vision Focused)
#
# | **Phase** | **Duration** | **Goal** | **Skills / Tools** | **Outputs / Projects** |
# |-----------|--------------|----------|---------------------|-------------------------|
# | **1. Embedded Systems & Automotive Foundations** | 2–3 months | Learn low-level automotive and embedded SW basics | - Modern C++ (17+)  <br>- AUTOSAR basics  <br>- CAN, LIN, FlexRay  <br>- Zephyr RTOS  <br>- AOSP build system, VHAL  <br>- Git, GitHub | - CAN simulator project  <br>- AAOS mockup app (Android Automotive)  <br>- Flash AOSP on emulator/hardware |
# | **2. Computer Vision & Edge AI** | 2–3 months | Build and deploy CV models on edge devices | - OpenCV, MediaPipe  <br>- YOLOv5/v8, DeepSort, Ultralytics  <br>- PyTorch, TFLite, TensorRT  <br>- Jetson Nano, Raspberry Pi  <br>- Model quantization & optimization (ONNX, TensorRT) | - Real-time object detection on Jetson/RPi  <br>- Quantized CV model pipeline (YOLO → TFLite/TensorRT)  <br>- Video frame processing pipeline |
# | **3. Microservices & Cloud Integration** | 2–3 months | Build scalable CV pipelines with APIs, databases, and cloud | - FastAPI, Flask  <br>- PostgreSQL, MongoDB  <br>- RTSP/IP camera integration  <br>- Async I/O, multiprocessing, threading  <br>- Docker, MQTT, Redis Streams  <br>- AWS/Azure basics | - Microservices-based CV app  <br>- Dockerized RTSP video analyzer  <br>- Database logging + live dashboard |
# | **4. System Management & Monitoring** | 1–2 months | Optimize system performance, enable monitoring and model tracking | - MLflow (experiment tracking)  <br>- Prometheus, Grafana, ELK stack  <br>- Profiling tools: perf, gprof  <br>- Android ADB/logcat  <br>- Basic CI/CD (GitHub Actions) | - Monitored CV pipeline with logs & alerts  <br>- MLflow-based model lifecycle  <br>- Benchmark: CPU vs GPU inference |
# | **5. Final Projects & Portfolio Building** | 1–2 months (ongoing updates) | Polish deliverables, resume, and visibility | - GitHub repo management  <br>- Readme writing  <br>- Personal branding: LinkedIn, blog posts | - Final portfolio with videos & writeups  <br>- Tailored CV for Eagle Vision  <br>- Technical posts (LinkedIn/Medium) |

# %% [markdown]
# ![ChatGPT Image May 3, 2025, 05_50_50 PM.png](<attachment:ChatGPT Image May 3, 2025, 05_50_50 PM.png>)

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import datetime, timedelta

# Define phases with start and duration
phases = [
    ("Embedded Systems & Automotive Foundations", 0, 90),
    ("Computer Vision & Edge AI", 90, 90),
    ("Microservices & Cloud Integration", 180, 90),
    ("System Management & Monitoring", 270, 60),
    ("Final Projects & Portfolio Building", 330, 60)
]

# Define topics for each phase
topics = {
    "Embedded Systems & Automotive Foundations": [
        "Modern C++", "AUTOSAR", "CAN/LIN/FlexRay", "Zephyr RTOS", "AOSP/VHAL", "Git/GitHub"
    ],
    "Computer Vision & Edge AI": [
        "OpenCV", "MediaPipe", "YOLO/Ultralytics", "DeepSort", "PyTorch", "TFLite", "TensorRT",
        "Jetson Nano", "Raspberry Pi", "Model Quantization"
    ],
    "Microservices & Cloud Integration": [
        "FastAPI", "Flask", "PostgreSQL", "MongoDB", "RTSP/IP cameras", "Async I/O", 
        "Multithreading/Multiprocessing", "Docker", "MQTT", "Redis Streams", "AWS", "Azure"
    ],
    "System Management & Monitoring": [
        "MLflow", "Prometheus", "Grafana", "ELK Stack", "perf/gprof", "ADB/logcat", "GitHub Actions"
    ],
    "Final Projects & Portfolio Building": [
        "GitHub Portfolio", "Readme Writing", "LinkedIn/Blog", "Resume/CV"
    ]
}

# Gantt chart base
start_date = datetime(2025, 5, 1)
fig, ax = plt.subplots(figsize=(14, 8))

for i, (phase, offset, duration) in enumerate(phases):
    phase_start = start_date + timedelta(days=offset)
    phase_end = phase_start + timedelta(days=duration)
    ax.barh(phase, duration, left=mdates.date2num(phase_start), height=0.6, align='center', label=phase)

# Configure axis
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))
ax.invert_yaxis()
plt.title("📊 Roadmap Gantt Chart: Path to Eagle Vision Role", fontsize=14)
plt.xlabel("Timeline")
plt.grid(True, which='both', axis='x', linestyle='--', linewidth=0.5)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_11056/970516807.py:52: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /home/ferganey/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
