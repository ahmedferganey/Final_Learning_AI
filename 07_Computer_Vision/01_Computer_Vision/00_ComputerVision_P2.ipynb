# %%
import cv2
import sys


s = 0
if len(sys.argv) > 1:
  s = sys.argv[1]

source = cv2.VideoCapture(s)

win_name = 'Camera Preview'
cv2.namedwindow(win_name, cv2.WINDOW_NORRMAL)


while cv2.waitkey(1) != 27:
  has_frame, frame = source.read()
  if not has_frame:
    break
  cv2.imshow(win_name, frame)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 12
#       9 source = cv2.VideoCapture(s)
#      11 win_name = 'Camera Preview'
# ---> 12 cv2.namedwindow(win_name, cv2.WINDOW_NORRMAL)
#      15 while cv2.waitkey(1) != 27:
#      16   has_frame, frame = source.read()
#
# AttributeError: module 'cv2' has no attribute 'namedwindow'
